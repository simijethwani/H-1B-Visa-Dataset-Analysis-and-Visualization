# %% [markdown]
# #### Import Related Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# download data set from this link
#
# https://www.kaggle.com/code/gpreda/h-1b-visa-applications/data

# %% [markdown]
# ### read csv in Pandas DataFrame

# %%
df = pd.read_csv('h1b_kaggle.csv')

# %%
df
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# ...             ...                  ...
# 3002453     3002454                  NaN
# 3002454     3002455                  NaN
# 3002455     3002456                  NaN
# 3002456     3002457                  NaN
# 3002457     3002458                  NaN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# ...

# %% [markdown]
# ### show columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### delete 'unnamed:0'  column from data set

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ## check no of rows in data frame

# %%
df.shape[0]
# Out:
# 3002458

# %% [markdown]
# ## Drop All rows which has any NA value and show first 5 rows after this operation

# %%
df = df.dropna()

# %%
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# ...

# %% [markdown]
# ## reset index and check how many rows you have

# %%
df.reset_index(inplace=True)

# %%
df.shape[0]
# Out:
# 2877765

# %% [markdown]
# ## Write a code to find out top 15 hiring company (Employer Name)

# %%
df['EMPLOYER_NAME'].value_counts().head()
# Out:
# EMPLOYER_NAME
# INFOSYS LIMITED                      130257
# TATA CONSULTANCY SERVICES LIMITED     64273
# WIPRO LIMITED                         45673
# DELOITTE CONSULTING LLP               35999
# IBM INDIA PRIVATE LIMITED             33585
# Name: count, dtype: int64

# %%
df['EMPLOYER_NAME'].value_counts().head(15).plot(kind='bar')
# Out:
# <Axes: xlabel='EMPLOYER_NAME'>

# %% [markdown]
# ### Top 15 companies which provide highest PREVALING WAGE

# %%
df['PREVAILING_WAGE'].value_counts().head()
# Out:
# PREVAILING_WAGE
# 60000.0    10185
# 55245.0     6745
# 62566.0     6480
# 58053.0     5683
# 52499.0     5492
# Name: count, dtype: int64

# %% [markdown]
# ##### Average PREVAILING WAGE

# %%
df['PREVAILING_WAGE'].mean()
# Out:
# 145166.64888401062

# %%
df[df['EMPLOYER_NAME']=='OMPI OF AMERICA INC.']
# Out:
#                  CASE_STATUS         EMPLOYER_NAME         SOC_NAME  \
# 2697835  CERTIFIED-WITHDRAWN  OMPI OF AMERICA INC.  Sales Engineers
#
#                                       JOB_TITLE FULL_TIME_POSITION  \
# 2697835  AREA MANAGER, PHARMACEUTICAL PACKAGING                  Y
#
#          PREVAILING_WAGE    YEAR            WORKSITE        lon        lat
# 2697835      212987840.0  2011.0  BROOKLYN, NEW YORK -73.944158  40.678178

# %%
df[['EMPLOYER_NAME','PREVAILING_WAGE']].groupby('EMPLOYER_NAME').mean().sort_values(by=['PREVAILING_WAGE'], ascending=False).head(15).plot(kind='bar',color=plt.cm.tab20.colors[:15])
# Out:
# <Axes: xlabel='EMPLOYER_NAME'>

# %%
f.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### Top 20 WORKSITE

# %%
df['WORKSITE'].value_counts().head(20)
# Out:
# WORKSITE
# NEW YORK, NEW YORK            190863
# HOUSTON, TEXAS                 83385
# SAN FRANCISCO, CALIFORNIA      62457
# ATLANTA, GEORGIA               52008
# CHICAGO, ILLINOIS              51167
# SAN JOSE, CALIFORNIA           49582
# SUNNYVALE, CALIFORNIA          34968
# DALLAS, TEXAS                  31509
# BOSTON, MASSACHUSETTS          31336
# REDMOND, WASHINGTON            30574
# CHARLOTTE, NORTH CAROLINA      30176
# IRVING, TEXAS                  29316
# MOUNTAIN VIEW, CALIFORNIA      29245
# SAN DIEGO, CALIFORNIA          28656
# SANTA CLARA, CALIFORNIA        27945
# JERSEY CITY, NEW JERSEY        26822
# SEATTLE, WASHINGTON            26745
# AUSTIN, TEXAS                  26695
# LOS ANGELES, CALIFORNIA        26393
# PHILADELPHIA, PENNSYLVANIA     24104
# Name: count, dtype: int64

# %%
df['WORKSITE'].value_counts().head(20).plot(kind='bar',color=plt.cm.tab20.colors[:15])
# Out:
# <Axes: xlabel='WORKSITE'>

# %% [markdown]
# ### head of Worksite Column

# %%
df['WORKSITE'].head()
# Out:
# 0        ANN ARBOR, MICHIGAN
# 1               PLANO, TEXAS
# 2    JERSEY CITY, NEW JERSEY
# 3           DENVER, COLORADO
# 4        ST. LOUIS, MISSOURI
# Name: WORKSITE, dtype: object

# %% [markdown]
# ### Show Column Names

# %%
df.columns[1:]
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### Apply a Function on DataFrame to gather only State Name from Worksite
#
#     eg. worksite name current -  SAN FRANCISCO, CALIFORNIA
#         worksite name after - CALIFORNIA
#
# **note**: there sholud not be any space at the begning or end of worksite name

# %%
df['STATE']=df['STATE'].apply(lambda x: x.strip().split(",")[1])

# %%
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002440            WITHDRAWN
# 3002441            WITHDRAWN
# 3002442            WITHDRAWN
# 3002443            WITHDRAWN
# 3002444            WITHDRAWN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002440                               ORACLE AMERICA, INC.
# 3002441                                 B & D DENTAL CORP.
# 3002442                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %%
df['WORKSITE'] = df['WORKSITE'].apply(lambda x : None if x=='MARIANA ISLANDS' else x)

# %% [markdown]
# **note:** if you view your analysis than you will find that 'MARIANA ISLANDS' worksite name is replaced with NA values

# %% [markdown]
# ### Replace all NA records in your Worksite Column with Value  'MARIANA ISLANDS'

# %%
df['WORKSITE'] = df['WORKSITE'].apply(lambda x : 'MARIANA ISLANDS' if x==None else x)

# %%
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002440            WITHDRAWN
# 3002441            WITHDRAWN
# 3002442            WITHDRAWN
# 3002443            WITHDRAWN
# 3002444            WITHDRAWN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002440                               ORACLE AMERICA, INC.
# 3002441                                 B & D DENTAL CORP.
# 3002442                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %% [markdown]
# ### Print out how many unique Worksites are there

# %%
df['WORKSITE'].value_counts().count()
# Out:
# 53

# %% [markdown]
# ##### show column names

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# #### Rename you column names as
#
#     {'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'}

# %%
df.rename(columns={'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'}, inplace=True)

# %%
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002440            WITHDRAWN
# 3002441            WITHDRAWN
# 3002442            WITHDRAWN
# 3002443            WITHDRAWN
# 3002444            WITHDRAWN
#
#                                                   EMPLOYER  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002440                               ORACLE AMERICA, INC.
# 3002441                                 B & D DENTAL CORP.
# 3002442                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %% [markdown]
# #### Now Remove all Columns Except these columns
#
#     'CASE_STATUS','YEAR','STATE','SOC_NAME','JOB_TITLE','FULL_T','PREV_WAGE','EMPLOYER','LON',"LAT"

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER', 'SOC_NAME', 'JOB_TITLE', 'FULL_T',
#        'PREV_WAGE', 'YEAR', 'STATE', 'LON', 'LAT'],
#       dtype='object')

# %% [markdown]
# #### Perform These Operations
#
#     Precise LON and LAT columns upto 2 decimal palaces
#
#     Convert YEAR Column into String
#
#     Convert PREV_WAGE column into Integer

# %%
df['LAT'] = df['LAT'].apply(lambda x:round(x,2))

# %%
df['LON'] = df['LON'].apply(lambda x:round(x,2))

# %%
df['YEAR'] = df['YEAR'].apply(lambda x : str(x) )

# %%
df['PREV_WAGE'] = df['PREV_WAGE'].apply(lambda x:int(round(x)))

# %% [markdown]
# __show top 3 values to check above operations__

# %%
df.head(3)
# Out:
#    index          CASE_STATUS                   EMPLOYER  \
# 0      0  CERTIFIED-WITHDRAWN     UNIVERSITY OF MICHIGAN
# 1      1  CERTIFIED-WITHDRAWN     GOODMAN NETWORKS, INC.
# 2      2  CERTIFIED-WITHDRAWN  PORTS AMERICA GROUP, INC.
#
#                         SOC_NAME                     JOB_TITLE FULL_T  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW      N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER      Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER      Y
#
#    PREV_WAGE    YEAR        STATE    LON    LAT
# 0      36067  2016.0     MICHIGAN -83.74  42.28
# 1     242674  2016.0        TEXAS -96.70  33.02
# 2     193066  2016.0   NEW JERSEY -74.08  40.73

# %%
# Out:
#            CASE_STATUS  YEAR       STATE                       SOC_NAME  \
# 0  CERTIFIED-WITHDRAWN  2016    MICHIGAN  BIOCHEMISTS AND BIOPHYSICISTS
# 1  CERTIFIED-WITHDRAWN  2016       TEXAS               CHIEF EXECUTIVES
# 2  CERTIFIED-WITHDRAWN  2016  NEW JERSEY               CHIEF EXECUTIVES
#
#                       JOB_TITLE FULL_T PREV_WAGE                   EMPLOYER  \
# 0  POSTDOCTORAL RESEARCH FELLOW      N     36067     UNIVERSITY OF MICHIGAN
# 1       CHIEF OPERATING OFFICER      Y    242674     GOODMAN NETWORKS, INC.
# 2         CHIEF PROCESS OFFICER      Y    193066  PORTS AMERICA GROUP, INC.
#
#      LON    LAT
# 0 -83.74  42.28
# 1 -96.70  33.02
# 2 -74.08  40.73

# %% [markdown]
# ### __show unique values of CASE_STATUS Column__

# %%
df['CASE_STATUS'].unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %% [markdown]
# # Calculate the petitions distributions by status

# %%
d = [var for var in df['CASE_STATUS'].value_counts()]

# %%
print(d)
# Out:
# [2512114, 195721, 85161, 84752, 15, 1, 1]

# %%
from matplotlib.pyplot import pie,axis,show
import matplotlib as mpl

# %% [markdown]
# #### PETITIONS BY CASE STATUS

# %%
df['CASE_STATUS'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Calculating the petitions distributions by year

# %%
r = [var for var in df['YEAR'].value_counts()]

# %%
r
# Out:
# [629299, 600120, 498027, 422427, 394267, 333625]

# %%
df['YEAR'].value_counts().sort_values().plot(title = 'petitions distributed by year',kind='bar',figsize=(10,3), stacked=True ,width=.9,color=plt.cm.tab20.colors[:6])
# Out:
# <Axes: title={'center': 'petitions distributed by year'}, xlabel='YEAR'>

# %%
sn.set_context("notebook",font_scale=1.0)
plt.figure(figsize=(13,3))
plt.title('petitions distributions by year')
sn.countplot(f['YEAR'])

# %%
denied = f[f.CASE_STATUS == 'DENIED']
len(denied)
# Out:
# 85161

# %%
del denied['CASE_STATUS']

# %%
denied = denied.reset_index()
denied.head(3)
# Out:
#    index  YEAR       STATE          SOC_NAME  \
# 0     39  2016  WASHINGTON  CHIEF EXECUTIVES
# 1     47  2016  CALIFORNIA  CHIEF EXECUTIVES
# 2     95  2016    ILLINOIS  CHIEF EXECUTIVES
#
#                                            JOB_TITLE FULL_T PREV_WAGE  \
# 0                            CHIEF EXECUTIVE OFFICER      Y    187200
# 1                                          PRESIDENT      Y    197683
# 2  PRINCIPAL (ATTORNEY) AND CHAIRMAN OF THE EXECU...      Y    226699
#
#                EMPLOYER     LON    LAT
# 0       PARALLELS, INC. -122.22  47.48
# 1  RANCHO LA PUERTA LLC -117.16  32.72
# 2   BAKER & MCKENZIE PC  -87.63  41.88

# %%
denied_year_count = [0]* 6

# %%
for i in range(0,6):
    denied_year_count[i] = denied[denied.YEAR == years[i]]['YEAR'].count()

# %%
denied_year_count
# Out:
# [25986, 18866, 10976, 10816, 10037, 8480]

# %% [markdown]
# ### Denied PETITIONS DISTRIBUTION BY YEAR

# %%
df1 = pd.DataFrame(df[df['CASE_STATUS']=='DENIED'])

# %%
df1['YEAR'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='YEAR'>

# %%
df['YEAR'].value_counts()
# Out:
# YEAR
# 2016.0    629299
# 2015.0    600120
# 2014.0    498027
# 2013.0    422427
# 2012.0    394267
# 2011.0    333625
# Name: count, dtype: int64

# %%
df1['YEAR'].value_counts()
# Out:
# YEAR
# 2011.0    25986
# 2012.0    18866
# 2013.0    10976
# 2014.0    10816
# 2015.0    10037
# 2016.0     8480
# Name: count, dtype: int64

# %% [markdown]
# #### Denied % Rate By Year

# %%
round((df1['YEAR'].value_counts())/(df['YEAR'].value_counts())*100 , 2)
# Out:
# YEAR
# 2011.0    7.79
# 2012.0    4.79
# 2013.0    2.60
# 2014.0    2.17
# 2015.0    1.67
# 2016.0    1.35
# Name: count, dtype: float64

# %%
round((df1['YEAR'].value_counts())/(df['YEAR'].value_counts())*100 , 2).plot(kind='bar' ,figsize=(10,3) , width=.9,color=plt.cm.tab20.colors[:6] )
# Out:
# <Axes: xlabel='YEAR'>

# %% [markdown]
# ## Calculate the number of petitions filed by the States

# %%
df['STATE'] = df['STATE'].apply(lambda x : x.strip())

# %%
df['STATE'].value_counts()
# Out:
# STATE
# CALIFORNIA              548539
# TEXAS                   286704
# NEW YORK                282429
# NEW JERSEY              206876
# ILLINOIS                154843
# MASSACHUSETTS           112659
# PENNSYLVANIA            103729
# WASHINGTON              100754
# FLORIDA                 100384
# GEORGIA                  99679
# VIRGINIA                 86948
# MICHIGAN                 77868
# NORTH CAROLINA           75701
# OHIO                     71765
# MARYLAND                 53145
# CONNECTICUT              48174
# MINNESOTA                45864
# ARIZONA                  40184
# MISSOURI                 32737
# WISCONSIN                30485
# COLORADO                 30231
# INDIANA                  28230
# TENNESSEE                25906
# OREGON                   22759
# DISTRICT OF COLUMBIA     22408
# DELAWARE                 17705
# IOWA                     15143
# ARKANSAS                 13775
# KANSAS                   12331
# UTAH                     12162
# ...

# %% [markdown]
# **unique stats sorted**

# %%
l = {var for var in df['STATE']}

# %%
la = [var for var in l]

# %%
print(la)
# Out:
# ['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA', 'COLORADO', 'CONNECTICUT', 'DELAWARE', 'DISTRICT OF COLUMBIA', 'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE', 'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA', 'PUERTO RICO', 'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE', 'TEXAS', 'UTAH', 'VERMONT', 'VIRGINIA', 'WASHINGTON', 'WEST VIRGINIA', 'WISCONSIN', 'WYOMING']

# %%
len(la)
# Out:
# 53

# %%
df['STATE'].value_counts().sort_index().plot(figsize=(15,5),title = 'FIELD PETITIONS BY STATE',xlabel='STATE',ylabel='FIELD PETITIONS',kind='bar',color=plt.cm.tab20.colors[:len(la)+1] )
# Out:
# <Axes: title={'center': 'FIELD PETITIONS BY STATE'}, xlabel='STATE', ylabel='FIELD PETITIONS'>

# %% [markdown]
# # Number of petitions denied by the state

# %% [markdown]
# __total denied petitions__

# %%
df[df['CASE_STATUS']=='DENIED'][['index']].value_counts().count()
# Out:
# 85161

# %%
z = pd.DataFrame(df[df['CASE_STATUS']=='DENIED'])

# %%
z['STATE'].value_counts().sort_index().plot(figsize=(15,5),title = 'DENIED PETITIONS BY STATE',xlabel='STATE',ylabel='DENIED PETITIONS',kind='bar',color=plt.cm.tab20.colors[:len(la)+1] )
# Out:
# <Axes: title={'center': 'DENIED PETITIONS BY STATE'}, xlabel='STATE', ylabel='DENIED PETITIONS'>

# %% [markdown]
# ## % Rate of Denied Petitions by State

# %%
round((z['STATE'].value_counts())/(df['STATE'].value_counts())*100 , 1).plot(kind='bar' ,figsize=(10,3) ,title = 'DENIED PETITIONS RATE in % BY STATE',xlabel='STATE',ylabel='DENIED PETITIONS %',color=plt.cm.tab20.colors[:len(la)+1] )
# Out:
# <Axes: title={'center': 'DENIED PETITIONS RATE in % BY STATE'}, xlabel='STATE', ylabel='DENIED PETITIONS %'>

# %% [markdown]
# #### Find out how many applied for Illinois State and how many how them are Denied

# %%
df[df['STATE'] == 'ILLINOIS'].value_counts().count()
# Out:
# 154843

# %%
df[(df['STATE'] == 'ILLINOIS') & (df['CASE_STATUS']=='DENIED')].value_counts().count()
# Out:
# 3612

# %% [markdown]
# #### How Many People are Certified for Job title 'CHIEF PROCESS OFFICER'  who applied for state  Illinois

# %%
df[(df['STATE'] == 'ILLINOIS') & (df['CASE_STATUS']=='CERTIFIED') & (df['JOB_TITLE'] == 'CHIEF PROCESS OFFICER' )]
# Out:
#            index CASE_STATUS                EMPLOYER             SOC_NAME  \
# 1256937  1295151   CERTIFIED  LITTLER MENDELSON P.C.  Management Analysts
# 1272268  1311111   CERTIFIED  LITTLER MENDELSON P.C.  Management Analysts
#
#                      JOB_TITLE FULL_T  PREV_WAGE    YEAR     STATE    LON  \
# 1256937  CHIEF PROCESS OFFICER      Y      67080  2014.0  ILLINOIS -87.63
# 1272268  CHIEF PROCESS OFFICER      Y      67080  2014.0  ILLINOIS -87.63
#
#            LAT
# 1256937  41.88
# 1272268  41.88

# %%
df[(df['STATE'] == 'ILLINOIS') & (df['CASE_STATUS']=='CERTIFIED') & (df['JOB_TITLE'] == 'CHIEF PROCESS OFFICER' )].value_counts().count()
# Out:
# 2

# %% [markdown]
# # Top 25 Job Titles

# %%
df['JOB_TITLE'].value_counts().head(25)
# Out:
# JOB_TITLE
# PROGRAMMER ANALYST             243357
# SOFTWARE ENGINEER              118897
# COMPUTER PROGRAMMER             68696
# SYSTEMS ANALYST                 60754
# SOFTWARE DEVELOPER              41875
# BUSINESS ANALYST                38781
# COMPUTER SYSTEMS ANALYST        34036
# TECHNOLOGY LEAD - US            28307
# SENIOR SOFTWARE ENGINEER        26617
# TECHNOLOGY ANALYST - US         26010
# ASSISTANT PROFESSOR             24436
# SENIOR CONSULTANT               24120
# CONSULTANT                      22643
# PROJECT MANAGER                 19015
# DATABASE ADMINISTRATOR          16108
# PHYSICAL THERAPIST              14203
# RESEARCH ASSOCIATE              13409
# COMPUTER PROGRAMMER ANALYST     13116
# ACCOUNTANT                      12934
# DEVELOPER                       12737
# ASSOCIATE                       12447
# ANALYST                         11644
# LEAD ENGINEER                   11012
# SENIOR SOFTWARE DEVELOPER       10031
# ...

# %%
df['JOB_TITLE'].value_counts().head(25).plot(figsize=(10,5),kind='bar',color=plt.cm.tab20.colors[:25])
# Out:
# <Axes: xlabel='JOB_TITLE'>
